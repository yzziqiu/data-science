# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
# %matplotlib inline
import csv
import snownlp

# %%
data = pd.read_csv("negpos-result.csv")
positive = []
negative = []
confidence = []
positive = data["items__positive_prob"]
negative = data["items__negative_prob"]
confidence = data["items__confidence"]

# %%
from snownlp import SnowNLP
sentences = data['text']
sentences
# Out:
# 0                                                    评论
# 1     这门课讲的确实不错，我都点怀疑是不是微信小程序团队的开发人员，或者就是赵小龙本人！！！哈哈，...
# 2     老师讲得很细腻，要听完一遍了，感觉老师是在用心教学，他不单单只是为了完成这个课程，更是在给我...
# 3     在慕课网看了这么多课程，最喜欢的老师，没有之一，授之以渔，不是授之以鱼。专门买了老师的书，结...
# 4     课程调理清晰，以实战电影详情及列表页等，让我这个菜鸟也能照着葫芦画个瓢耶！好老师，好课程。老...
# 5     一直以来对css的组织及复用感到很头疼，一旦有需求变动总会手动修改不少地方还容易出bug，写...
# 6     听老师的课程，受益匪浅，满满的干货，从跳槽面试的课程中学习到了很多平时不注意的点，很感谢老师...
# 7     做前端也有段时间了, css这块一直觉得没什么可提升的，但是看了老师的课程，对css这块有了...
# 8     课程很棒，听完后受益匪浅，对组件化又有了新的认识，正在用学到的知识修改以前的项目，写起来效率...
# 9                       之前听了老师的前段跳槽面试技巧那门课，觉得受益颇多，满满的干活
# 10    来慕课不长时间，第一次花钱买的就是老师的课，当时自己还在为面试苦恼，怎么自己实力这么差，面一...
# 11    老师讲的很好，学习路线明确，由浅入深，逻辑清晰，不仅讲述各个知识点，而且讲解知识点原理和解决...
# 12    前几章我都有跟着视频敲代码，这样可以开发工具和一些代码规范。后面几章直接学习老师的思想逻辑和...
# 13    老师讲的很棒,有点后悔现在才来学这个课程,里面的知识点面面俱到,还帮你扩充了前端需要理解的一...
# 14    老师讲的非常好 但是 有没有群可以加一下 因为有时候自己做还是会出现问题 版本更新了啊 之类...
# 15                                觉得不错，如果声音录制能更专业就更好了，，
# 16       这视频真的很棒，不知道老师有没有兴趣和时间再出一套关于vue的视频，非常想要听老师讲解vue
# ...

# %%
for sentence in sentences:
    print(sentence)
# Out:
# 评论
# 这门课讲的确实不错，我都点怀疑是不是微信小程序团队的开发人员，或者就是赵小龙本人！！！哈哈，点个赞，想学小程序，这门课无疑是最好的选择
# 老师讲得很细腻，要听完一遍了，感觉老师是在用心教学，他不单单只是为了完成这个课程，更是在给我们讲人生，因为程序或许只是我们生活中的一部分，但是学编程就像是在学生活，bug在鼓励我们不要放弃他，就好像是我们生活的的一些不如意再告诉我们挺过去又是美好的一天。感谢老师对我们的鼓励和教导，给老师点n个赞
# 在慕课网看了这么多课程，最喜欢的老师，没有之一，授之以渔，不是授之以鱼。专门买了老师的书，结合起来看，很详细，避免了很多弯路
# 课程调理清晰，以实战电影详情及列表页等，让我这个菜鸟也能照着葫芦画个瓢耶！好老师，好课程。老师继续讲课，我还要听。
# 一直以来对css的组织及复用感到很头疼，一旦有需求变动总会手动修改不少地方还容易出bug，写vue有一段时间了，总是对组件的抽象和项目的组织不太清晰，总感觉自己做的东西总是需要再优化，听了老师的项目组织思路，对项目的把控更加有心得了，之前也学过老师的es6课程，感觉同样帮帮哒，想能独当一面自己科学完整构建项目的同学不能错过老师的这门课程
# 听老师的课程，受益匪浅，满满的干货，从跳槽面试的课程中学习到了很多平时不注意的点，很感谢老师的梳理，打算年后找工作，这门课老师讲的太详细了，听了很多遍，每次收获都不同，从项目构建到上线，模块化开发，这是以前都不怎么关注的，好期待后面的课程。老师热心的指导，群里小伙伴很积极，能学到很多知识，支持支持，赞赞！
# 做前端也有段时间了, css这块一直觉得没什么可提升的，但是看了老师的课程，对css这块有了新的了解，更深的认识，模块化的css可以让代码更精简，更灵活，这门课真的挺值。尤其是第三章和第四章，这两章节融合了老师多年的工作经验，老师把自己对整个项目架构的分析，模块化要注意到的点都很详细都告诉给大家，这些平时可不会有人来跟我们说这些，当然，后面章节更精彩，小伙伴们别犹豫啦，赶快来学习吧！
# 课程很棒，听完后受益匪浅，对组件化又有了新的认识，正在用学到的知识修改以前的项目，写起来效率确实高了很多。
# 之前听了老师的前段跳槽面试技巧那门课，觉得受益颇多，满满的干活
# ...

# %%
s1 = SnowNLP(sentences[0])
s1.sentiments
# Out:
# 0.3913043478260875

# %%
senti =[]
senti_score =[]
for i in sentences:
  a1 = SnowNLP(i)
  a2 = a1.sentiments
  senti.append(i) # 语序...
  senti_score.append(a2)
table = pd.DataFrame(senti_score, senti)
table
# Out:
#                                                            0
# 评论                                                  0.391304
# 这门课讲的确实不错，我都点怀疑是不是微信小程序团队的开发人员，或者就是赵小龙本人！！！哈哈，点...  0.999464
# 老师讲得很细腻，要听完一遍了，感觉老师是在用心教学，他不单单只是为了完成这个课程，更是在给我们...  1.000000
# 在慕课网看了这么多课程，最喜欢的老师，没有之一，授之以渔，不是授之以鱼。专门买了老师的书，结合...  0.999948
# 课程调理清晰，以实战电影详情及列表页等，让我这个菜鸟也能照着葫芦画个瓢耶！好老师，好课程。老师...  0.999857
# 一直以来对css的组织及复用感到很头疼，一旦有需求变动总会手动修改不少地方还容易出bug，写v...  1.000000
# 听老师的课程，受益匪浅，满满的干货，从跳槽面试的课程中学习到了很多平时不注意的点，很感谢老师的...  1.000000
# 做前端也有段时间了, css这块一直觉得没什么可提升的，但是看了老师的课程，对css这块有了新...  1.000000
# 课程很棒，听完后受益匪浅，对组件化又有了新的认识，正在用学到的知识修改以前的项目，写起来效率确...  0.999790
# 之前听了老师的前段跳槽面试技巧那门课，觉得受益颇多，满满的干活                     0.999673
# 来慕课不长时间，第一次花钱买的就是老师的课，当时自己还在为面试苦恼，怎么自己实力这么差，面一个...  1.000000
# 老师讲的很好，学习路线明确，由浅入深，逻辑清晰，不仅讲述各个知识点，而且讲解知识点原理和解决问...  1.000000
# 前几章我都有跟着视频敲代码，这样可以开发工具和一些代码规范。后面几章直接学习老师的思想逻辑和解...  1.000000
# 老师讲的很棒,有点后悔现在才来学这个课程,里面的知识点面面俱到,还帮你扩充了前端需要理解的一些...  1.000000
# ...

# %%
# add sentiment to new column
data['senti_score'] = senti_score
data
# Out:
#                  log_id                                               text  \
# 0   7358017417485962294                                                 评论
# 1   4967986063139691750  这门课讲的确实不错，我都点怀疑是不是微信小程序团队的开发人员，或者就是赵小龙本人！！！哈哈，...
# 2   5131672469339143633  老师讲得很细腻，要听完一遍了，感觉老师是在用心教学，他不单单只是为了完成这个课程，更是在给我...
# 3   5546162725742882606  在慕课网看了这么多课程，最喜欢的老师，没有之一，授之以渔，不是授之以鱼。专门买了老师的书，结...
# 4   4900411236171595036  课程调理清晰，以实战电影详情及列表页等，让我这个菜鸟也能照着葫芦画个瓢耶！好老师，好课程。老...
# 5   2600240065988993268  一直以来对css的组织及复用感到很头疼，一旦有需求变动总会手动修改不少地方还容易出bug，写...
# 6   6784250449486616161  听老师的课程，受益匪浅，满满的干货，从跳槽面试的课程中学习到了很多平时不注意的点，很感谢老师...
# 7    692209952026579332  做前端也有段时间了, css这块一直觉得没什么可提升的，但是看了老师的课程，对css这块有了...
# 8   3384366390382915897  课程很棒，听完后受益匪浅，对组件化又有了新的认识，正在用学到的知识修改以前的项目，写起来效率...
# 9   7176583373243453706                    之前听了老师的前段跳槽面试技巧那门课，觉得受益颇多，满满的干活
# 10  2033861296348239242  来慕课不长时间，第一次花钱买的就是老师的课，当时自己还在为面试苦恼，怎么自己实力这么差，面一...
# ...

# %%
from snownlp import SnowNLP
sentences = data['text']
sentences
senti =[]
senti_score =[]
for i in sentences:
  a1 = SnowNLP(i)
  a2 = a1.sentiments
  senti.append(i) # 语序...
  senti_score.append(a2)
table = pd.DataFrame(senti_score, senti)
table
# Out:
#                                                            0
# 评论                                                  0.391304
# 这门课讲的确实不错，我都点怀疑是不是微信小程序团队的开发人员，或者就是赵小龙本人！！！哈哈，点...  0.999464
# 老师讲得很细腻，要听完一遍了，感觉老师是在用心教学，他不单单只是为了完成这个课程，更是在给我们...  1.000000
# 在慕课网看了这么多课程，最喜欢的老师，没有之一，授之以渔，不是授之以鱼。专门买了老师的书，结合...  0.999948
# 课程调理清晰，以实战电影详情及列表页等，让我这个菜鸟也能照着葫芦画个瓢耶！好老师，好课程。老师...  0.999857
# 一直以来对css的组织及复用感到很头疼，一旦有需求变动总会手动修改不少地方还容易出bug，写v...  1.000000
# 听老师的课程，受益匪浅，满满的干货，从跳槽面试的课程中学习到了很多平时不注意的点，很感谢老师的...  1.000000
# 做前端也有段时间了, css这块一直觉得没什么可提升的，但是看了老师的课程，对css这块有了新...  1.000000
# 课程很棒，听完后受益匪浅，对组件化又有了新的认识，正在用学到的知识修改以前的项目，写起来效率确...  0.999790
# 之前听了老师的前段跳槽面试技巧那门课，觉得受益颇多，满满的干活                     0.999673
# 来慕课不长时间，第一次花钱买的就是老师的课，当时自己还在为面试苦恼，怎么自己实力这么差，面一个...  1.000000
# 老师讲的很好，学习路线明确，由浅入深，逻辑清晰，不仅讲述各个知识点，而且讲解知识点原理和解决问...  1.000000
# 前几章我都有跟着视频敲代码，这样可以开发工具和一些代码规范。后面几章直接学习老师的思想逻辑和解...  1.000000
# 老师讲的很棒,有点后悔现在才来学这个课程,里面的知识点面面俱到,还帮你扩充了前端需要理解的一些...  1.000000
# ...

# %%
text["items__positive_prob"]=positive
text["items__negative_prob"]=negative
text["items__confidence"]=confidence
text['senti_score'] = senti_score
text
# Out:
#                  log_id                                               text  \
# 0   7358017417485962294                                                 评论
# 1   4967986063139691750  这门课讲的确实不错，我都点怀疑是不是微信小程序团队的开发人员，或者就是赵小龙本人！！！哈哈，...
# 2   5131672469339143633  老师讲得很细腻，要听完一遍了，感觉老师是在用心教学，他不单单只是为了完成这个课程，更是在给我...
# 3   5546162725742882606  在慕课网看了这么多课程，最喜欢的老师，没有之一，授之以渔，不是授之以鱼。专门买了老师的书，结...
# 4   4900411236171595036  课程调理清晰，以实战电影详情及列表页等，让我这个菜鸟也能照着葫芦画个瓢耶！好老师，好课程。老...
# 5   2600240065988993268  一直以来对css的组织及复用感到很头疼，一旦有需求变动总会手动修改不少地方还容易出bug，写...
# 6   6784250449486616161  听老师的课程，受益匪浅，满满的干货，从跳槽面试的课程中学习到了很多平时不注意的点，很感谢老师...
# 7    692209952026579332  做前端也有段时间了, css这块一直觉得没什么可提升的，但是看了老师的课程，对css这块有了...
# 8   3384366390382915897  课程很棒，听完后受益匪浅，对组件化又有了新的认识，正在用学到的知识修改以前的项目，写起来效率...
# 9   7176583373243453706                    之前听了老师的前段跳槽面试技巧那门课，觉得受益颇多，满满的干活
# 10  2033861296348239242  来慕课不长时间，第一次花钱买的就是老师的课，当时自己还在为面试苦恼，怎么自己实力这么差，面一...
# ...

# %%
data.to_csv("output.csv", encoding='utf-8')

# %%
NR_Count=dict(text['评论'].value_counts(sort=False))

# %%
def NR_Count(course):
    if course=='All':
        df=text
    else:
        df=text[text['课程名']==course]
    count=dict(df['评论'].value_counts())
    Unique_reason=list(text['评论'].unique())
    Unique_reason=[x for x in Unique_reason if str(x) != 'nan']
    Reason_frame=pd.DataFrame({'Reasons':Unique_reason})
    Reason_frame['count']=Reason_frame['Reasons'].apply(lambda x: count[x])
    return Reason_frame

# %%
# Set values for various parameters
num_features = 300    # Word vector dimensionality                      
min_word_count = 40   # Minimum word count                        
num_workers = 4       # Number of threads to run in parallel
context = 7           # Context window size                                                                                    
downsampling = 1e-3   # Downsample setting for frequent words

# %%
import re
def normalizer(text):
    only_letters = re.sub("[^a-zA-Z]", " ",text) 
    s = SnowNLP(text)
    s.words
    #tokens = nltk.word_tokenize(only_letters)[2:]
    #lower_case = [l.lower() for l in tokens]

# %%
text['normalized_tweet'] = text["评论"].apply(normalizer)

# %%
from gensim.models import word2vec
model = word2vec.Word2Vec(text.normalized_tweet, workers=num_workers, \
                          size=num_features, min_count = min_word_count, \
                          window = context, sample = downsampling)
model.init_sims(replace=True)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
X = model[model.wv.vocab]
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)
plt.rcParams["figure.figsize"] = (20,20)
plt.scatter(X_tsne[:, 0], X_tsne[:, 1])
labels = list(model.wv.vocab.keys())
for label, x, y in zip(labels, X_tsne[:, 0], X_tsne[:, 1]):
    plt.annotate(
        label,
        xy=(x, y), xytext=(-1, -1),
        textcoords='offset points', ha='right', va='bottom')

plt.show()
